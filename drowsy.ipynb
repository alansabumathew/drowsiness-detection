# %% [markdown]
# ## 1. Installing Dependencies

# %%
# !pip install torch torchvision torchaudio

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt

# %%
# !pip install matplotlib

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ## 2. Load

# %%
model=torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in C:\Users\alanm/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-6-26 Python-3.8.6 torch-2.0.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# ## 3. Detection

# %%
img='https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters:format(jpg)/https://specials-images.forbesimg.com/dam/imageserve/650774250/0x0.jpg%3Ffit%3Dscale'

# %%
results=model(img)
results.print()
# Out:
# image 1/1: 796x1200 14 persons
# Speed: 1018.3ms pre-process, 619.4ms inference, 308.8ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
np.squeeze(results.render()).shape
# Out:
# (796, 1200, 3)

# %% [markdown]
# ## 4. Real Time Detection

# %%
# For webcam
cap=cv2.VideoCapture(0)
while cap.isOpened():
    ret,frame=cap.read()
    
    #make detections
    results=model(frame)
    
    cv2.imshow('YOLO',np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# For video file
cap=cv2.VideoCapture('messi.mp4')
while cap.isOpened():
    ret,frame=cap.read()
    
    #make detections
    results=model(frame)
    
    cv2.imshow('YOLO',np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 5. Training

# %%
import uuid #unique identifier
import os
import time

# %%
IMAGES_PATH=os.path.join('
                         ges')
# labels=['awake','drowsy']
number_imgs=40

# %%
cap=cv2.VideoCapture(0)
labels=['awake','drowsy']
#loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label,img_num))
        
        #web cam feed
        ret,frame=cap.read()
        #naming image path
        imgname=os.path.join(IMAGES_PATH,label+'.'+str(uuid.uuid1())+'.jpg')
        #writes out image to file
        cv2.imwrite(imgname,frame)
        #render to the screen
        cv2.imshow('Image Collection',frame)
        #delay between captures
        time.sleep(2)
        if cv2.waitKey(10) & 0xFF==ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Out:
# ...
# data\images\drowsy.cc4c74ed-0cff-11ee-8fe4-38f3abb7db43
# ...
# data\images\drowsy.cc4c74ee-0cff-11ee-8cbb-38f3abb7db43
# ...
# data\images\drowsy.cc4c74ef-0cff-11ee-b0a5-38f3abb7db43
# ...
# data\images\drowsy.cc4c74f0-0cff-11ee-a19d-38f3abb7db43
# ...
# data\images\drowsy.cc4c74f1-0cff-11ee-b6c4-38f3abb7db43
# ...
# data\images\drowsy.cc4c74f2-0cff-11ee-90ca-38f3abb7db43
# ...
# data\images\drowsy.cc4c74f3-0cff-11ee-9118-38f3abb7db43
# ...
# data\images\drowsy.cc4c74f4-0cff-11ee-960d-38f3abb7db43
# ...
# data\images\drowsy.cc4c74f5-0cff-11ee-8719-38f3abb7db43
# ...
# data\images\drowsy.cc4c74f6-0cff-11ee-adfe-38f3abb7db43
# ...
# data\images\drowsy.cc4c74f7-0cff-11ee-a3e0-38f3abb7db43
# ...
# data\images\drowsy.cc4c74f8-0cff-11ee-985e-38f3abb7db43
# ...
# data\images\drowsy.cc4c74f9-0cff-11ee-b8c3-38f3abb7db43
# ...
# data\images\drowsy.cc4c74fa-0cff-11ee-b738-38f3abb7db43
# ...
# data\images\drowsy.cc4c74fb-0cff-11ee-b607-38f3abb7db43
# ...
# data\images\drowsy.cc4c74fc-0cff-11ee-8717-38f3abb7db43
# ...
# data\images\drowsy.cc4c74fd-0cff-11ee-854a-38f3abb7db43
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade

# %%
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 640 --batch 16 --epochs 5 --data dataset.yaml --weights yolov5s.pt --workers 2
# Out:
# ^C

# %% [markdown]
# ## 6. Load

# %%
model=torch.hub.load('ultralytics/yolov5','custom',path='yolov5/runs/train/exp13/weights/last.pt',force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\alanm/.cache\torch\hub\master.zip
# YOLOv5  2023-7-6 Python-3.8.6 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img=os.path.join('data','images','awake.3eb0a7cf-0dce-11ee-a7e3-38f3abb7db43.jpg')

# %%
results=model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 awake
# Speed: 24.0ms pre-process, 330.1ms inference, 0.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap=cv2.VideoCapture(0)
while cap.isOpened():
    ret,frame=cap.read()
    
    results=model(frame)
    
    cv2.imshow('YOLO',np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 5
#       2 while cap.isOpened():
#       3     ret,frame=cap.read()
# ----> 5     results=model(frame)
#       7     cv2.imshow('YOLO',np.squeeze(results.render()))
#       9     if cv2.waitKey(10) & 0xFF==ord('q'):
#
# File ~\Desktop\Drowsiness Detection\yolo\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
# ...
